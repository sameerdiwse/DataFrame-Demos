# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('D:\\Python\\Sample_CSVs\\area.csv')
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df['prices'])
df
# Out:
#    area  prices
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel('Year')
plt.ylabel('Temp in Fh')
plt.scatter(df.area,df.prices, color='red', marker="o")
plt.plot(df.area, reg.predict(df[['area']]), color='green')

# %%
reg.predict([[3700]])
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([683030.82191781])

# %%
reg.coef_
# Out:
# array([0.0070583])

# %%
reg.intercept_
# Out:
# np.float64(-1138.4957721406317)
